# %%
# Import the necessary libraries
import numpy as np                              # For numerical computations
import pandas as pd                             # For handling datasets
from sklearn.model_selection import train_test_split # For splitting data into training and testing sets
from sklearn.feature_extraction.text import CountVectorizer # For converting text to numerical features
import scipy.sparse                             # For working with sparse matrices
from keras.models import Sequential             # For creating a neural network model
from keras.layers import Dense                  # For adding layers to the neural network
from sklearn.metrics import classification_report



# Load the dataset
dataset = pd.read_csv('fraud_email_.csv')

# Replace NaN values with empty strings
dataset = dataset.fillna('')
X = dataset['Text'].values                       # Extract the text from the dataset
y = dataset['Class'].values                      # Extract the target variable (label) from the dataset


# Convert the text to numerical features using bag-of-words representation
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(X)

# Total number of samples
n_samples = X.shape[0]
n_train = int(n_samples * 0.8) # Use 80% of samples for training

# Create the sparse matrix for the training and testing data
X_train = scipy.sparse.csr_matrix(X[:n_train, :])
X_test = scipy.sparse.csr_matrix(X[n_train:, :])

# Sort the indices of the sparse matrix
X_train.sort_indices()
X_test.sort_indices()

# Split the dataset into training and testing sets, with 80% for training and 20% for testing
y_train = y[:n_train]
y_test = y[n_train:]


# Create the neural network model
model = Sequential()                            # Create an instance of the sequential model
model.add(Dense(units=16, activation='relu', input_dim=X_train.shape[1])) # Add a dense layer with 16 units and ReLU activation function as the input layer
model.add(Dense(units=8, activation='relu'))    # Add a dense layer with 8 units and ReLU activation function
model.add(Dense(units=1, activation='sigmoid')) # Add a dense layer with 1 unit and sigmoid activation function as the output layer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy']) # Compile the model with the Adam optimizer, binary cross-entropy loss function, and accuracy metric

import matplotlib.pyplot as plt

# Train the model and save the history
history = model.fit(X_train, y_train, batch_size=32, epochs=100, validation_data=(X_test, y_test))  # Train the model on the training data with a batch size of 32, 100 epochs, and validation data for evaluating the model's performance during training

# Plot the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# Test the model and get the classification report
y_pred = model.predict(X_test)                 # Use the trained model to predict the target variable for the testing data
y_pred = (y_pred > 0.5)                        # Convert the predicted probabilities to binary predictions (1 if the probability is greater than 0.5, 0 otherwise)
print(classification_report(y_test, y_pred))

# Evaluate the model
from sklearn.metrics import confusion_matrix   # Import the confusion matrix from sklearn
cm = confusion_matrix(y_test, y_pred)           # Compute the confusion matrix using the predicted and actual target variables for the testing data
print(cm)                                       # Print the confusion matrix
# Out:
# Epoch 1/100
# 299/299 [==============================] - 8s 24ms/step - loss: 0.1612 - accuracy: 0.9745 - val_loss: 0.0565 - val_accuracy: 0.9832
# Epoch 2/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0302 - accuracy: 0.9890 - val_loss: 0.0396 - val_accuracy: 0.9832
# Epoch 3/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0171 - accuracy: 0.9946 - val_loss: 0.0407 - val_accuracy: 0.9874
# Epoch 4/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0116 - accuracy: 0.9971 - val_loss: 0.0303 - val_accuracy: 0.9899
# Epoch 5/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0072 - accuracy: 0.9987 - val_loss: 0.0297 - val_accuracy: 0.9899
# Epoch 6/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.0313 - val_accuracy: 0.9891
# Epoch 7/100
# 299/299 [==============================] - 8s 25ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0351 - val_accuracy: 0.9887
# Epoch 8/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.0370 - val_accuracy: 0.9891
# Epoch 9/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0345 - val_accuracy: 0.9891
# Epoch 10/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0404 - val_accuracy: 0.9887
# Epoch 11/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0502 - val_accuracy: 0.9870
# Epoch 12/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0486 - val_accuracy: 0.9874
# Epoch 13/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0433 - val_accuracy: 0.9887
# Epoch 14/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0496 - val_accuracy: 0.9878
# Epoch 15/100
# 299/299 [==============================] - 8s 25ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0523 - val_accuracy: 0.9878
# Epoch 16/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0410 - val_accuracy: 0.9891
# Epoch 17/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0608 - val_accuracy: 0.9862
# Epoch 18/100
# 299/299 [==============================] - 7s 25ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0525 - val_accuracy: 0.9878
# Epoch 19/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0447 - val_accuracy: 0.9887
# Epoch 20/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0641 - val_accuracy: 0.9862
# Epoch 21/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0560 - val_accuracy: 0.9870
# Epoch 22/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0729 - val_accuracy: 0.9862
# Epoch 23/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0699 - val_accuracy: 0.9862
# Epoch 24/100
# 299/299 [==============================] - 8s 25ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0812 - val_accuracy: 0.9858
# Epoch 25/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0794 - val_accuracy: 0.9858
# Epoch 26/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0627 - val_accuracy: 0.9878
# Epoch 27/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0475 - val_accuracy: 0.9887
# Epoch 28/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0628 - val_accuracy: 0.9878
# Epoch 29/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0840 - val_accuracy: 0.9862
# Epoch 30/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0617 - val_accuracy: 0.9878
# Epoch 31/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0991 - val_accuracy: 0.9858
# Epoch 32/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0735 - val_accuracy: 0.9866
# Epoch 33/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0841 - val_accuracy: 0.9862
# Epoch 34/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0852 - val_accuracy: 0.9862
# Epoch 35/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0728 - val_accuracy: 0.9870
# Epoch 36/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1165 - val_accuracy: 0.9853
# Epoch 37/100
# 299/299 [==============================] - 7s 25ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0270 - val_accuracy: 0.9925
# Epoch 38/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0458 - val_accuracy: 0.9899
# Epoch 39/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0466 - val_accuracy: 0.9899
# Epoch 40/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0666 - val_accuracy: 0.9878
# Epoch 41/100
# 299/299 [==============================] - 8s 25ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0877 - val_accuracy: 0.9866
# Epoch 42/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0821 - val_accuracy: 0.9874
# Epoch 43/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0863 - val_accuracy: 0.9870
# Epoch 44/100
# 299/299 [==============================] - 8s 25ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1084 - val_accuracy: 0.9853
# Epoch 45/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0993 - val_accuracy: 0.9858
# Epoch 46/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1105 - val_accuracy: 0.9862
# Epoch 47/100
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0788 - val_accuracy: 0.9878
# Epoch 48/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0820 - val_accuracy: 0.9883
# Epoch 49/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0914 - val_accuracy: 0.9874
# Epoch 50/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0722 - val_accuracy: 0.9883
# Epoch 51/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1220 - val_accuracy: 0.9862
# Epoch 52/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1357 - val_accuracy: 0.9858
# Epoch 53/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0912 - val_accuracy: 0.9874
# Epoch 54/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1399 - val_accuracy: 0.9858
# Epoch 55/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1341 - val_accuracy: 0.9866
# Epoch 56/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0881 - val_accuracy: 0.9878
# Epoch 57/100
# 299/299 [==============================] - 8s 25ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1305 - val_accuracy: 0.9874
# Epoch 58/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.0481 - val_accuracy: 0.9920
# Epoch 59/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0507 - val_accuracy: 0.9912
# Epoch 60/100
# 299/299 [==============================] - 7s 25ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0523 - val_accuracy: 0.9908
# Epoch 61/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0600 - val_accuracy: 0.9908
# Epoch 62/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0644 - val_accuracy: 0.9899
# Epoch 63/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0687 - val_accuracy: 0.9899
# Epoch 64/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0753 - val_accuracy: 0.9899
# Epoch 65/100
# 299/299 [==============================] - 7s 25ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0759 - val_accuracy: 0.9895
# Epoch 66/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0711 - val_accuracy: 0.9895
# Epoch 67/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0852 - val_accuracy: 0.9899
# Epoch 68/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0836 - val_accuracy: 0.9895
# Epoch 69/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0891 - val_accuracy: 0.9899
# Epoch 70/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1055 - val_accuracy: 0.9895
# Epoch 71/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1000 - val_accuracy: 0.9895
# Epoch 72/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1141 - val_accuracy: 0.9895
# Epoch 73/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1135 - val_accuracy: 0.9895
# Epoch 74/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1023 - val_accuracy: 0.9891
# Epoch 75/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1035 - val_accuracy: 0.9891
# Epoch 76/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1110 - val_accuracy: 0.9891
# Epoch 77/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1215 - val_accuracy: 0.9891
# Epoch 78/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1037 - val_accuracy: 0.9891
# Epoch 79/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1352 - val_accuracy: 0.9891
# Epoch 80/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1205 - val_accuracy: 0.9891
# Epoch 81/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1107 - val_accuracy: 0.9887
# Epoch 82/100
# 299/299 [==============================] - 7s 25ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1432 - val_accuracy: 0.9891
# Epoch 83/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0818 - val_accuracy: 0.9895
# Epoch 84/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0978 - val_accuracy: 0.9895
# Epoch 85/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1260 - val_accuracy: 0.9891
# Epoch 86/100
# 299/299 [==============================] - 7s 24ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1157 - val_accuracy: 0.9891
# Epoch 87/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1462 - val_accuracy: 0.9887
# Epoch 88/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1429 - val_accuracy: 0.9891
# Epoch 89/100
# 299/299 [==============================] - 7s 25ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1100 - val_accuracy: 0.9891
# Epoch 90/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1334 - val_accuracy: 0.9891
# Epoch 91/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1421 - val_accuracy: 0.9891
# Epoch 92/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1234 - val_accuracy: 0.9887
# Epoch 93/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0831 - val_accuracy: 0.9895
# Epoch 94/100
# 299/299 [==============================] - 7s 25ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1236 - val_accuracy: 0.9895
# Epoch 95/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1298 - val_accuracy: 0.9895
# Epoch 96/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1208 - val_accuracy: 0.9891
# Epoch 97/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1057 - val_accuracy: 0.9895
# Epoch 98/100
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1231 - val_accuracy: 0.9891
# Epoch 99/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1575 - val_accuracy: 0.9878
# Epoch 100/100
# 299/299 [==============================] - 8s 25ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1331 - val_accuracy: 0.9891
# 75/75 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1327
#            1       1.00      0.98      0.99      1059
#
#     accuracy                           0.99      2386
#    macro avg       0.99      0.99      0.99      2386
# weighted avg       0.99      0.99      0.99      2386
#
# [[1326    1]
#  [  25 1034]]
