# %%
# Import the necessary libraries
import numpy as np                              # For numerical computations
import pandas as pd                             # For handling datasets
from sklearn.model_selection import train_test_split # For splitting data into training and testing sets
from sklearn.feature_extraction.text import CountVectorizer # For converting text to numerical features
import scipy.sparse                             # For working with sparse matrices
from keras.models import Sequential             # For creating a neural network model
from keras.layers import Dense                  # For adding layers to the neural network
from sklearn.metrics import classification_report



# Load the dataset
dataset = pd.read_csv('fraud_email_.csv')

# Replace NaN values with empty strings
dataset = dataset.fillna('')
X = dataset['Text'].values                       # Extract the text from the dataset
y = dataset['Class'].values                      # Extract the target variable (label) from the dataset


# Convert the text to numerical features using bag-of-words representation
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(X)

# Total number of samples
n_samples = X.shape[0]
n_train = int(n_samples * 0.8) # Use 80% of samples for training

# Create the sparse matrix for the training and testing data
X_train = scipy.sparse.csr_matrix(X[:n_train, :])
X_test = scipy.sparse.csr_matrix(X[n_train:, :])

# Sort the indices of the sparse matrix
X_train.sort_indices()
X_test.sort_indices()

# Split the dataset into training and testing sets, with 80% for training and 20% for testing
y_train = y[:n_train]
y_test = y[n_train:]


# Create the neural network model
model = Sequential()                            # Create an instance of the sequential model
model.add(Dense(units=16, activation='relu', input_dim=X_train.shape[1])) # Add a dense layer with 16 units and ReLU activation function as the input layer
model.add(Dense(units=8, activation='relu'))    # Add a dense layer with 8 units and ReLU activation function
model.add(Dense(units=1, activation='sigmoid')) # Add a dense layer with 1 unit and sigmoid activation function as the output layer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy']) # Compile the model with the Adam optimizer, binary cross-entropy loss function, and accuracy metric

# Train the model
model.fit(X_train, y_train, batch_size=32, epochs=100, validation_data=(X_test, y_test)) # Train the model on the training data with a batch size of 32, 100 epochs, and validation data for evaluating the model's performance during training

# Test the model and get the classification report
y_pred = model.predict(X_test)                 # Use the trained model to predict the target variable for the testing data
y_pred = (y_pred > 0.5)                        # Convert the predicted probabilities to binary predictions (1 if the probability is greater than 0.5, 0 otherwise)
print(classification_report(y_test, y_pred))

# Evaluate the model
from sklearn.metrics import confusion_matrix   # Import the confusion matrix from sklearn
cm = confusion_matrix(y_test, y_pred)           # Compute the confusion matrix using the predicted and actual target variables for the testing data
print(cm)                                       # Print the confusion matrix
# Out:
# Epoch 1/100
# 299/299 [==============================] - 14s 42ms/step - loss: 0.1596 - accuracy: 0.9709 - val_loss: 0.0554 - val_accuracy: 0.9820
# Epoch 2/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0284 - accuracy: 0.9905 - val_loss: 0.0398 - val_accuracy: 0.9866
# Epoch 3/100
# 299/299 [==============================] - 12s 39ms/step - loss: 0.0143 - accuracy: 0.9961 - val_loss: 0.0433 - val_accuracy: 0.9870
# Epoch 4/100
# 299/299 [==============================] - 11s 37ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.0295 - val_accuracy: 0.9899
# Epoch 5/100
# 299/299 [==============================] - 12s 39ms/step - loss: 0.0049 - accuracy: 0.9988 - val_loss: 0.0352 - val_accuracy: 0.9883
# Epoch 6/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0451 - val_accuracy: 0.9874
# Epoch 7/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0460 - val_accuracy: 0.9874
# Epoch 8/100
# 299/299 [==============================] - 13s 43ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0554 - val_accuracy: 0.9883
# Epoch 9/100
# 299/299 [==============================] - 10s 35ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0686 - val_accuracy: 0.9862
# Epoch 10/100
# 299/299 [==============================] - 12s 40ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0754 - val_accuracy: 0.9858
# Epoch 11/100
# 299/299 [==============================] - 13s 43ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0822 - val_accuracy: 0.9866
# Epoch 12/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.1026 - val_accuracy: 0.9853
# Epoch 13/100
# 299/299 [==============================] - 10s 35ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0914 - val_accuracy: 0.9866
# Epoch 14/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1096 - val_accuracy: 0.9866
# Epoch 15/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0438 - val_accuracy: 0.9899
# Epoch 16/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0578 - val_accuracy: 0.9883
# Epoch 17/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0687 - val_accuracy: 0.9891
# Epoch 18/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0876 - val_accuracy: 0.9853
# Epoch 19/100
# 299/299 [==============================] - 9s 32ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0907 - val_accuracy: 0.9862
# Epoch 20/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0967 - val_accuracy: 0.9862
# Epoch 21/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1476 - val_accuracy: 0.9853
# Epoch 22/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1386 - val_accuracy: 0.9849
# Epoch 23/100
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1448 - val_accuracy: 0.9853
# Epoch 24/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1285 - val_accuracy: 0.9853
# Epoch 25/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1485 - val_accuracy: 0.9853
# Epoch 26/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1521 - val_accuracy: 0.9853
# Epoch 27/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1372 - val_accuracy: 0.9853
# Epoch 28/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1442 - val_accuracy: 0.9853
# Epoch 29/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 0.0264 - val_accuracy: 0.9916
# Epoch 30/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0330 - val_accuracy: 0.9920
# Epoch 31/100
# 299/299 [==============================] - 10s 35ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0404 - val_accuracy: 0.9912
# Epoch 32/100
# 299/299 [==============================] - 9s 32ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0423 - val_accuracy: 0.9916
# Epoch 33/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0465 - val_accuracy: 0.9916
# Epoch 34/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0554 - val_accuracy: 0.9908
# Epoch 35/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0544 - val_accuracy: 0.9908
# Epoch 36/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0624 - val_accuracy: 0.9904
# Epoch 37/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0627 - val_accuracy: 0.9904
# Epoch 38/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0723 - val_accuracy: 0.9904
# Epoch 39/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0754 - val_accuracy: 0.9904
# Epoch 40/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0872 - val_accuracy: 0.9899
# Epoch 41/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0939 - val_accuracy: 0.9899
# Epoch 42/100
# 299/299 [==============================] - 12s 39ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0954 - val_accuracy: 0.9895
# Epoch 43/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0496 - val_accuracy: 0.9912
# Epoch 44/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0542 - val_accuracy: 0.9908
# Epoch 45/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0774 - val_accuracy: 0.9912
# Epoch 46/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0754 - val_accuracy: 0.9912
# Epoch 47/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0825 - val_accuracy: 0.9908
# Epoch 48/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0791 - val_accuracy: 0.9904
# Epoch 49/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0959 - val_accuracy: 0.9904
# Epoch 50/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1005 - val_accuracy: 0.9899
# Epoch 51/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1022 - val_accuracy: 0.9899
# Epoch 52/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1286 - val_accuracy: 0.9895
# Epoch 53/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1389 - val_accuracy: 0.9891
# Epoch 54/100
# 299/299 [==============================] - 11s 35ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1437 - val_accuracy: 0.9891
# Epoch 55/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1544 - val_accuracy: 0.9887
# Epoch 56/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0791 - val_accuracy: 0.9899
# Epoch 57/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0741 - val_accuracy: 0.9899
# Epoch 58/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0943 - val_accuracy: 0.9899
# Epoch 59/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1209 - val_accuracy: 0.9904
# Epoch 60/100
# 299/299 [==============================] - 12s 40ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1177 - val_accuracy: 0.9904
# Epoch 61/100
# 299/299 [==============================] - 12s 39ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1217 - val_accuracy: 0.9904
# Epoch 62/100
# 299/299 [==============================] - 10s 35ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1350 - val_accuracy: 0.9895
# Epoch 63/100
# 299/299 [==============================] - 12s 39ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1537 - val_accuracy: 0.9887
# Epoch 64/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1513 - val_accuracy: 0.9891
# Epoch 65/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1779 - val_accuracy: 0.9883
# Epoch 66/100
# 299/299 [==============================] - 10s 35ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1424 - val_accuracy: 0.9887
# Epoch 67/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1714 - val_accuracy: 0.9883
# Epoch 68/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1513 - val_accuracy: 0.9887
# Epoch 69/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0886 - val_accuracy: 0.9899
# Epoch 70/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1217 - val_accuracy: 0.9899
# Epoch 71/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1295 - val_accuracy: 0.9899
# Epoch 72/100
# 299/299 [==============================] - 10s 35ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1254 - val_accuracy: 0.9899
# Epoch 73/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1743 - val_accuracy: 0.9883
# Epoch 74/100
# 299/299 [==============================] - 12s 39ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1690 - val_accuracy: 0.9883
# Epoch 75/100
# 299/299 [==============================] - 11s 35ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0920 - val_accuracy: 0.9891
# Epoch 76/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1306 - val_accuracy: 0.9891
# Epoch 77/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1339 - val_accuracy: 0.9895
# Epoch 78/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1656 - val_accuracy: 0.9883
# Epoch 79/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1794 - val_accuracy: 0.9878
# Epoch 80/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1718 - val_accuracy: 0.9883
# Epoch 81/100
# 299/299 [==============================] - 11s 35ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1528 - val_accuracy: 0.9891
# Epoch 82/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1885 - val_accuracy: 0.9866
# Epoch 83/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1828 - val_accuracy: 0.9866
# Epoch 84/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0365 - accuracy: 0.9991 - val_loss: 0.0823 - val_accuracy: 0.9891
# Epoch 85/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0050 - accuracy: 0.9996 - val_loss: 0.0527 - val_accuracy: 0.9916
# Epoch 86/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0540 - val_accuracy: 0.9904
# Epoch 87/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0559 - val_accuracy: 0.9904
# Epoch 88/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0576 - val_accuracy: 0.9904
# Epoch 89/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0572 - val_accuracy: 0.9904
# Epoch 90/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0581 - val_accuracy: 0.9904
# Epoch 91/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0585 - val_accuracy: 0.9904
# Epoch 92/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0603 - val_accuracy: 0.9904
# Epoch 93/100
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0596 - val_accuracy: 0.9904
# Epoch 94/100
# 299/299 [==============================] - 12s 40ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0603 - val_accuracy: 0.9904
# Epoch 95/100
# 299/299 [==============================] - 11s 37ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0609 - val_accuracy: 0.9904
# Epoch 96/100
# 299/299 [==============================] - 12s 40ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0606 - val_accuracy: 0.9904
# Epoch 97/100
# 299/299 [==============================] - 12s 39ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0628 - val_accuracy: 0.9904
# Epoch 98/100
# 299/299 [==============================] - 12s 38ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0621 - val_accuracy: 0.9904
# Epoch 99/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0630 - val_accuracy: 0.9904
# Epoch 100/100
# 299/299 [==============================] - 11s 37ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0636 - val_accuracy: 0.9904
# 75/75 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1327
#            1       1.00      0.98      0.99      1059
#
#     accuracy                           0.99      2386
#    macro avg       0.99      0.99      0.99      2386
# weighted avg       0.99      0.99      0.99      2386
#
# [[1322    5]
#  [  18 1041]]
